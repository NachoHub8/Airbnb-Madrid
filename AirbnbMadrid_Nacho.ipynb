# %% [markdown]
# # <span style="color:grey">           Airbnb MADRID </span>
#     Realizado por: Jose Ignacio Pérez España

# %% [markdown]
# # <span style="color:gold"> Librerías </span>

# %%
#importamos las librerías necesarias
import numpy as np
import pandas as pd

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# # <span style="color:gold"> Carga </span>

# %%
#cargamos el dataset
df = pd.read_csv(r"C:\Users\Usuario\Desktop\Upgrade Hub\Nacho\madrid.csv")

# %%
df   #verificamos la carga
# Out:
#              id                                             name    host_id  \
# 0          6369         Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                             Bright and airy room      83531
# 2         23001                Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                           Gran Via Studio Madrid     101471
# 4         24836                   Select the Madrid more "cool".     101653
# ...         ...                                              ...        ...
# 20221  45415398               The Molino Nest ** City Center Apt  257822045
# 20222  45415840  Habitación con zona chill y balcón C/Fuencarral    1891477
# 20223  45416012          Se alquila habitación con baño privado.   33266182
# 20224  45416146                              Estudio en malasaña  353683552
# 20225  45417194                         Habitación san Cristóbal  360742569
#
# ...

# %% [markdown]
# # <span style="color:gold"> Preprocesamiento y Análisis exploratorio </span>
#
# Primer paso: Metadatos del Conjunto de datos.
#
# Segundo paso: Reparacion de valores nulos y/o atipicos.
#
# Tercer paso: Analisis descriptivo de las variables
#
# Cuarto paso: Representacion grafica.

# %% [markdown]
# ## <span style="color:gold"> Primer paso: Metadatos del conjunto de datos.  </span>
#
# Atributos básicos de pandas

# %%
df.shape
# Out:
# (20226, 16)

# %%
df.size
# Out:
# 323616

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20226 non-null  int64
#  1   name                            20223 non-null  object
#  2   host_id                         20226 non-null  int64
#  3   host_name                       20221 non-null  object
#  4   neighbourhood_group             20226 non-null  object
#  5   neighbourhood                   20226 non-null  object
#  6   latitude                        20226 non-null  float64
#  7   longitude                       20226 non-null  float64
#  8   room_type                       20226 non-null  object
#  9   price                           20226 non-null  int64
#  10  minimum_nights                  20226 non-null  int64
#  11  number_of_reviews               20226 non-null  int64
# ...

# %%
df.head()
# Out:
#       id                                      name  host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom    13660     Simon
# 1  21853                      Bright and airy room    83531     Abdel
# 2  23001         Apartmento Arganzuela- Madrid Rio    82175     Jesus
# 3  24805                    Gran Via Studio Madrid   101471    Iraido
# 4  24836            Select the Madrid more "cool".   101653     Tenty
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40341   -3.74084     Private room
# 2          Arganzuela         Legazpi  40.38695   -3.69304  Entire home/apt
# 3              Centro     Universidad  40.42202   -3.70395  Entire home/apt
# 4              Centro        Justicia  40.41995   -3.69764  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df.tail()
# Out:
#              id                                             name    host_id  \
# 20221  45415398               The Molino Nest ** City Center Apt  257822045
# 20222  45415840  Habitación con zona chill y balcón C/Fuencarral    1891477
# 20223  45416012          Se alquila habitación con baño privado.   33266182
# 20224  45416146                              Estudio en malasaña  353683552
# 20225  45417194                         Habitación san Cristóbal  360742569
#
#       host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 20221    Thomas              Centro    Universidad  40.42403   -3.70447
# 20222     Diogo              Centro       Justicia  40.42619   -3.70111
# 20223  Patricia               Usera      Orcasitas  40.36918   -3.70632
# 20224     Jorge              Centro    Universidad  40.42507   -3.70278
# 20225   Abraham          Villaverde  San Cristobal  40.34459   -3.68980
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
#traducimos las variables
df.rename(columns={"name" : "nombre", "host_id" : "id afitrion", "host_name" : "nombre anfitrion", "neighbourhood_group": "barrio_agrupado", "neighbourhood": "barrio", "latitude" : "latitud", "longitude" : "longitud", "room_type" : "habitacion_tipo", "price" : "precio", "minimum_nights" : "noches_minimas", "number_of_reviews": "numero_visitas", "last_review" : "ultima_visita", "last_review" : "ultima_visita", "reviews_per_month" : "visita_mes", "calculated_host_listings_count" : "lista_calculada", "availability_365" : "disponibilidad_anual"}, inplace = True)

# %% [markdown]
# ## <span style="color:gold"> Segundo paso: Reparación de valores nulos y/o atípicos. </span>

# %%
df.isnull().sum().sum()
# Out:
# 10514

# %%
df.isnull().sum()
# Out:
# id                         0
# nombre                     3
# id afitrion                0
# nombre anfitrion           5
# barrio_agrupado            0
# barrio                     0
# latitud                    0
# longitud                   0
# habitacion_tipo            0
# precio                     0
# noches_minimas             0
# numero_visitas             0
# ultima_visita           5253
# visita_mes              5253
# lista_calculada            0
# disponibilidad_anual       0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# id                       0.000000
# nombre                   0.014832
# id afitrion              0.000000
# nombre anfitrion         0.024721
# barrio_agrupado          0.000000
# barrio                   0.000000
# latitud                  0.000000
# longitud                 0.000000
# habitacion_tipo          0.000000
# precio                   0.000000
# noches_minimas           0.000000
# numero_visitas           0.000000
# ultima_visita           25.971522
# visita_mes              25.971522
# lista_calculada          0.000000
# disponibilidad_anual     0.000000
# dtype: float64

# %%
#Aplicamos un mapa de calor ya que son los mas recomendables para visualizar los valores nulos. Con ello visualizamos la distribucion, podemos comprobar patrones y tendencias.
sns.heatmap(data=df.isnull(), yticklabels=False, cbar=False)  #con la libreria seaborn
# Out:
# <AxesSubplot: >

# %%
df = df.drop(columns=["ultima_visita", "visita_mes"])

# %% [markdown]
# ## <span style="color:gold">Tercer paso: Análisis descriptivo de las variables. </span>

# %%
df = df.drop(columns=["id", "id afitrion"])

# %%
df = df.drop(columns=["latitud", "longitud"])

# %%
df5 = df.describe()
df5
# Out:
#              precio  noches_minimas  numero_visitas  lista_calculada  \
# count  20226.000000    20226.000000    20226.000000     20226.000000
# mean     115.860773        5.489766       34.115940        11.072481
# std      317.566208       29.281089       64.987894        28.626750
# min        0.000000        1.000000        0.000000         1.000000
# 25%       35.000000        1.000000        0.000000         1.000000
# 50%       59.000000        2.000000        6.000000         2.000000
# 75%       99.000000        3.000000       36.000000         6.000000
# max    11600.000000     1125.000000      657.000000       213.000000
#
#        disponibilidad_anual
# count          20226.000000
# mean             163.920202
# std              146.080268
# min                0.000000
# 25%                0.000000
# 50%              127.000000
# 75%              345.000000
# max              365.000000

# %%
#q3-q1 = x  75% + x*1,5

# %%
(99)+((99-35)*1.5)   #superior al resultado lo consideramos valores atipicos por lo que debemos prescindir de ellos.
# Out:
# 195.0

# %%
df["precio"].value_counts().to_frame()
# Out:
#      precio
# 30      576
# 25      573
# 50      561
# 40      550
# 35      526
# ..      ...
# 645       1
# 825       1
# 396       1
# 643       1
# 826       1
#
# [542 rows x 1 columns]

# %%
df["precio"][11600]    #esto me busca la fila 11600 no ese precio
# Out:
# 184

# %%
df[df["precio"]==11600]
# Out:
#                                                  nombre nombre anfitrion  \
# 3518           LOFT IN DOWNTOWN WITH A/C. MADRID CENTER  Andrea Y Daniel
# 17198  Luminoso apartamento con terraza junto al Retiro           Narita
#
#       barrio_agrupado  barrio  habitacion_tipo  precio  noches_minimas  \
# 3518           Centro  Cortes  Entire home/apt   11600               3
# 17198          Retiro   Ibiza  Entire home/apt   11600               1
#
#        numero_visitas  lista_calculada  disponibilidad_anual
# 3518              217               10                     0
# 17198               5                1                     0

# %%
df.iloc[11600]
# Out:
# nombre                  Gran Apartamento en Madrid Centro. ¡50% Descue...
# nombre anfitrion                                        Fernando & Ramiro
# barrio_agrupado                                                    Centro
# barrio                                                                Sol
# habitacion_tipo                                           Entire home/apt
# precio                                                                184
# noches_minimas                                                          1
# numero_visitas                                                         42
# lista_calculada                                                        13
# disponibilidad_anual                                                  341
# Name: 11600, dtype: object

# %%
df[df["barrio_agrupado"]=="Centro"].mean()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3740\1558514398.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# precio                  100.987024
# noches_minimas            4.823927
# numero_visitas           49.179449
# lista_calculada          12.882477
# disponibilidad_anual    165.771495
# dtype: float64

# %%
df[df["barrio_agrupado"]=="Centro"].describe()
# Out:
#              precio  noches_minimas  numero_visitas  lista_calculada  \
# count   9479.000000     9479.000000     9479.000000      9479.000000
# mean     100.987024        4.823927       49.179449        12.882477
# std      261.601438       24.873903       79.482676        30.259556
# min        0.000000        1.000000        0.000000         1.000000
# 25%       42.000000        1.000000        1.000000         1.000000
# 50%       65.000000        2.000000       12.000000         3.000000
# 75%      100.000000        3.000000       64.000000        10.000000
# max    11600.000000     1125.000000      657.000000       213.000000
#
#        disponibilidad_anual
# count           9479.000000
# mean             165.771495
# std              144.922704
# min                0.000000
# 25%                1.000000
# 50%              134.000000
# 75%              341.000000
# max              365.000000

# %%
df.groupby(["barrio_agrupado"])["precio"].describe()
# Out:
#                         count        mean         std   min   25%   50%  \
# barrio_agrupado
# Arganzuela             1040.0   87.930769  328.185209   0.0  32.0  49.0
# Barajas                 177.0  119.542373  236.342057  14.0  28.0  41.0
# Carabanchel             673.0   70.255572  181.419215   9.0  22.0  36.0
# Centro                 9479.0  100.987024  261.601438   0.0  42.0  65.0
# Chamartín               554.0  118.010830  184.657622  14.0  40.0  67.0
# Chamberí               1243.0  125.406275  347.935466   9.0  35.0  58.0
# Ciudad Lineal           688.0  102.674419  230.934804   8.0  25.0  40.0
# Fuencarral - El Pardo   318.0  118.242138  261.499319  10.0  29.0  50.0
# Hortaleza               377.0  134.002653  271.425507  10.0  29.0  52.0
# Latina                  642.0  127.448598  437.555746   9.0  22.0  38.0
# Moncloa - Aravaca       542.0  102.719557  194.050851   9.0  30.0  53.5
# Moratalaz               124.0   95.766129  169.554659  12.0  23.0  32.5
# ...

# %%
df_p = df[["precio"]]    #doble corchete lo convierte a dataframe directamente

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20226 entries, 0 to 20225
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   precio  20226 non-null  int64
# dtypes: int64(1)
# memory usage: 158.1 KB

# %%
#plt.boxplot(df["precio"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cefc1500d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cefc150610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cefc12fdf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cefc150b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cefc150df0>],
#  'means': []}

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.facecolor':'lightgrey', 'figure.edgecolor':'lightgrey'})
ax = sns.boxplot(data=df, x='precio', y='alojamientos', color='orange').set(title='distribucion del precio')
ax = sns.stripplot(data=df, x='precio', y='alojamientos', color='blue')
ax.set_ylabel('alojamientos')
ax.set_xlabel('precio')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 3
#       1 sns.set_style('darkgrid')
#       2 sns.set(rc={'figure.facecolor':'lightgrey', 'figure.edgecolor':'lightgrey'})
# ----> 3 ax = sns.boxplot(data=df, x='precio', y='alojamientos', color='orange').set(title='distribucion del precio')
#       4 ax = sns.stripplot(data=df, x='precio', y='alojamientos', color='blue')
#       5 ax.set_ylabel('alojamientos')
#
# File c:\Users\Usuario\Desktop\Upgrade Hub\upgrade_analytics\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
# ...

# %%
precio_alto = df[df["precio"]>=1000]
precio_alto
# Out:
#                                                   nombre nombre anfitrion  \
# 1376                   Habitación doble en centro Madrid             Javi
# 1653                 Fantastico Piso Barrio de Salamanca      Juan Andres
# 2075                      Awsome space  in the downtown.          Roberto
# 2271       Cozy flat in the heart of Madrid - Superhost!            David
# 2328                   1 MAGDALENA 38, QUIET AND CENTRAL            Nuria
# ...                                                  ...              ...
# 18739  Great 150m2 furnished flat with 4 double beds ...             Mike
# 18740  beautiful 3rd floor, 1-bedroom apartment on Ca...             Mike
# 18741    Cosy 1-bedroom apartment for rent in Centro CIN             Mike
# 18742        Duplex near Rafaela Ibarra with A/C (SANB6)             Mike
# 18950  Nice and practical apartment for couples in th...             Mike
#
#       barrio_agrupado            barrio  habitacion_tipo  precio  \
# ...

# %%
precio_alto.describe()
# Out:
#              precio  noches_minimas  numero_visitas  lista_calculada  \
# count    336.000000      336.000000      336.000000       336.000000
# mean    1744.592262        8.184524        4.851190        53.300595
# std     1634.723787       82.074639       25.657943        63.886902
# min     1000.000000        1.000000        0.000000         1.000000
# 25%     1162.000000        1.000000        0.000000         1.000000
# 50%     1169.000000        1.000000        0.000000         3.000000
# 75%     1500.000000        1.000000        1.000000       133.000000
# max    11600.000000     1125.000000      287.000000       133.000000
#
#        disponibilidad_anual
# count            336.000000
# mean             147.056548
# std              132.205290
# min                0.000000
# 25%               21.750000
# 50%               90.000000
# 75%              250.000000
# max              365.000000

# %%
sns.histplot(precio_alto["precio"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 sns.histplot(precio_alto["precio"])
#
# File c:\Users\Usuario\Desktop\Upgrade Hub\upgrade_analytics\lib\site-packages\plotly\basedatatypes.py:746, in BaseFigure.__getitem__(self, prop)
#     744         return self._frames_validator.present(self._frame_objs)
#     745     else:
# --> 746         raise KeyError(orig_prop)
#     748 # Handle non-scalar case
#     749 # ----------------------
#     750 # e.g. ('foo', 1)
#     751 else:
#     752     err = _check_path_in_prop_tree(self, orig_prop, error_cast=PlotlyKeyError)
#
# KeyError: 'precio'

# %%
precio_alto = px.scatter(df, x = "precio",
    title="Distribución de precios altos de Madrid",

    opacity=1,
    color_discrete_sequence=['lightgreen'],
    template="plotly_dark"
)
precio_alto.update_layout(
    xaxis_title="Precio",
    yaxis_title="alojamientos"
)

precio_alto.show()

# %%
df["precio"].describe()
# Out:
# count    20226.000000
# mean       115.860773
# std        317.566208
# min          0.000000
# 25%         35.000000
# 50%         59.000000
# 75%         99.000000
# max      11600.000000
# Name: precio, dtype: float64

# %%
(18286*100)/20226
# Out:
# 90.40838524671216

# %%
20226-18286
# Out:
# 1940

# %% [markdown]
# el 90.40% de los datos se encuentran en el rango de precios 0-195.
# Habrá que analizar porqué hay alojamientos por 0€

# %%
precio = df[df["precio"]<=195]
precio["precio"].describe()
# Out:
# count    18286.000000
# mean        62.471508
# std         38.538690
# min          0.000000
# 25%         33.000000
# 50%         53.000000
# 75%         82.000000
# max        195.000000
# Name: precio, dtype: float64

# %%
sns.histplot(precio["precio"])
# Out:
# <AxesSubplot: xlabel='precio', ylabel='Count'>

# %%
df[df["precio"]<=1]
# Out:
#                     nombre     nombre anfitrion barrio_agrupado    barrio  \
# 17917  Hotel Santo Domingo  Hotel Santo Domingo          Centro   Palacio
# 17918         Petit Hostel         Petit Hostel      Arganzuela  Imperial
#
#       habitacion_tipo  precio  noches_minimas  numero_visitas  \
# 17917      Hotel room       0               1               0
# 17918      Hotel room       0               1               0
#
#        lista_calculada  disponibilidad_anual
# 17917                1                     0
# 17918                1                     0

# %%
# Utilizar el estilo de fondo oscuro
plt.style.use('dark_background')

# Generar datos de ejemplo
precio

# Crear el histograma
plt.hist(precio, bins = 40, color = "grey")

# Agregar títulos y etiquetas
plt.title("Distribución del precio sin atípicos")
plt.xlabel("Frecuencia")
plt.ylabel("Precio")

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 8
#       5 precio
#       7 # Crear el histograma
# ----> 8 plt.hist(precio, bins = 40, color = "grey")
#      10 # Agregar títulos y etiquetas
#      11 plt.title("Distribución del precio sin atípicos")
#
# File c:\Users\Usuario\Desktop\Upgrade Hub\upgrade_analytics\lib\site-packages\matplotlib\pyplot.py:2573, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2567 @_copy_docstring_and_deprecators(Axes.hist)
#    2568 def hist(
#    2569         x, bins=None, range=None, density=False, weights=None,
#    2570         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2571         orientation='vertical', rwidth=None, log=False, color=None,
# ...

# %%
df["barrio_agrupado"].value_counts().count()
# Out:
# 21

# %%
dist_barrios = df["barrio_agrupado"].value_counts()
dist_barrios
# Out:
# Centro                   9479
# Salamanca                1341
# Chamberí                 1243
# Arganzuela               1040
# Tetuán                    805
# Ciudad Lineal             688
# Carabanchel               673
# Latina                    642
# Chamartín                 554
# Moncloa - Aravaca         542
# Puente de Vallecas        539
# San Blas - Canillejas     527
# Retiro                    501
# Hortaleza                 377
# Fuencarral - El Pardo     318
# Usera                     317
# Villaverde                179
# Barajas                   177
# Moratalaz                 124
# Villa de Vallecas          95
# Vicálvaro                  65
# Name: barrio_agrupado, dtype: int64

# %%
plt.style.use('dark_background')

# %%
sns.countplot(y= df["barrio_agrupado"])     #ordenarlos!!!! 
# Utilizar el estilo de fondo oscuro
# Out:
# <AxesSubplot: xlabel='count', ylabel='barrio_agrupado'>

# %%
fig = plt.figure(figsize=(12, 12)) 
plt.pie(dist_barrios, autopct='%1.1f%%', textprops={'color':'black'});

# %% [markdown]
# ## <span style="color:gold">Cuarto paso: Análisis bivariante y multivariante. Y Representación gráfica. </span>

# %% [markdown]
# ### <span style="color:gold">Matriz de Correlaciones</span>

# %%
#mapa de calor   #en diagonal
matriz_c = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(matriz_c, annot=True,annot_kws={"size": 10}, vmin=-1.0, vmax=1.0,cmap="crest")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3740\3529371594.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz_c = df.corr()
# <AxesSubplot: >

# %% [markdown]
# # <span style="color:gold"> Conclusiones </span>

# %% [markdown]
# A pesar de lo que se podría pensar no hay ninguna correlación significativa entre las distitas variables. Es decir, ninguna variable es explicativa del precio.
